# %%
# For Colab
repository = "CS-Net"
# %cd /content/drive/MyDrive/Git/{repository}
# !ls
# Out:
# /content/drive/MyDrive/Git/CS-Net
# checkpoint		    dataloader	predict3d.py  train.py
# cs2net.md		    dataset	predict.py    url.txt
# CS_net.ipynb		    LICENSE	README.md     utils
# cuda-keyring_1.0-1_all.deb  model	train3d.py    visdomlog.txt

# %%
# Git things
# For Git
email = "yvnminc@gmail.com"
username = "yvnminc"
# !git config --global user.email {email}
# !git config --global user.name {username}

# !git add .
# !git commit -m "Run CS-net sucessfully"
# !git push

# %%
# Installs
# !pip install visdom
# !pip install SimpleITK
# !pip install vtk

# %%
# !python train.py
# Out:
# ---------------start training------------------
# dataset/DRIVE
# [1:1] --- loss:0.3119159639	acc:0.1955	sen:0.7890
# [1:2] --- loss:0.3137479722	acc:0.1960	sen:0.6556
# [1:3] --- loss:0.3039156795	acc:0.2099	sen:0.6274
# Start testing model...
# dataset/DRIVE
# 	---	 test acc:0.0591    test sen:1.0000
# Average acc:0.0591, average sen:1.0000
# [2:4] --- loss:0.2977737784	acc:0.1865	sen:0.6802
# [2:5] --- loss:0.2935447991	acc:0.2226	sen:0.7584
# [2:6] --- loss:0.2747244835	acc:0.1902	sen:0.7654
# Start testing model...
# dataset/DRIVE
# 	---	 test acc:0.0592    test sen:1.0000
# Average acc:0.0592, average sen:1.0000
# [3:7] --- loss:0.2829651237	acc:0.1846	sen:0.8452
# [3:8] --- loss:0.2773486376	acc:0.2504	sen:0.8057
# [3:9] --- loss:0.2792505026	acc:0.2179	sen:0.9010
# Start testing model...
# dataset/DRIVE
# 	---	 test acc:0.0596    test sen:1.0000
# Average acc:0.0596, average sen:1.0000
# [4:10] --- loss:0.2588498592	acc:0.2381	sen:0.8088
# ...
