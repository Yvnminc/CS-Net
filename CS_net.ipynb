# %%
# For Colab
repository = "CS-Net"
# %cd /content/drive/MyDrive/Git/{repository}
# !ls

# # Installs
# !pip install visdom
# !pip install SimpleITK
# !pip install vtk
# Out:
# /content/drive/MyDrive/Git/CS-Net
# checkpoint		    dataloader	predict3d.py  train.py	visdomlog.txt
# cs2net.md		    dataset	predict.py    untitled
# CS_net.ipynb		    LICENSE	README.md     url.txt
# cuda-keyring_1.0-1_all.deb  model	train3d.py    utils

# %%
from dataloader import drive
data_path = "dataset/DRIVE"

images, groundtruth = drive.load_dataset(data_path, train=True)

# %%
# Git things
# For Git
email = "yvnminc@gmail.com"
username = "yvnminc"
# !git config --global user.email {email}
# !git config --global user.name {username}

# !git add .
# !git commit -m "Delete unnecessary packages"
# !git push
# Out:
# [master b4e692b] Delete unnecessary packages
#  7 files changed, 5 insertions(+), 5 deletions(-)
#  rewrite CS_net.ipynb (96%)
# Counting objects: 13, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (13/13), done.
# Writing objects: 100% (13/13), 4.23 KiB | 722.00 KiB/s, done.
# Total 13 (delta 9), reused 0 (delta 0)
# remote: Resolving deltas: 100% (9/9), completed with 9 local objects.
# remote: This repository moved. Please use the new location:
# remote:   https://github.com/Yvnminc/CS-Net.git
# To https://github.com/yvnminc/CS-Net
#    986b7fb..b4e692b  master -> master

# %%
# !python train.py --epochs 1000
# Out:
# Streaming output truncated to the last 5000 lines.
# Average acc:0.9782, average sen:0.9155
# [288:862] --- loss:0.0536533520	acc:0.9597	sen:0.7095
# [288:863] --- loss:0.0436983518	acc:0.9709	sen:0.8114
# [288:864] --- loss:0.0481685437	acc:0.9646	sen:0.7619
# Start testing model...
# dataset/DRIVE
# 	---	 test acc:0.9795    test sen:0.8909
# Average acc:0.9795, average sen:0.8909
# [289:865] --- loss:0.0451519117	acc:0.9708	sen:0.7206
# [289:866] --- loss:0.0528054684	acc:0.9543	sen:0.7354
# [289:867] --- loss:0.0656131804	acc:0.9485	sen:0.5203
# Start testing model...
# dataset/DRIVE
# 	---	 test acc:0.9812    test sen:0.8639
# Average acc:0.9812, average sen:0.8639
# [290:868] --- loss:0.0534921512	acc:0.9534	sen:0.8032
# [290:869] --- loss:0.0412491336	acc:0.9743	sen:0.8450
# [290:870] --- loss:0.0450303108	acc:0.9663	sen:0.8239
# Start testing model...
# dataset/DRIVE
# 	---	 test acc:0.9827    test sen:0.8588
# Average acc:0.9827, average sen:0.8588
# ...

# %%
# !python predict.py
# Out:
# ./dataset/./DRIVE/test/images/01_test.tif
# torch.Size([1, 3, 512, 512])
# /usr/local/lib/python3.9/dist-packages/torch/nn/functional.py:1967: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# output saving successfully
# ./dataset/./DRIVE/test/images/03_test.tif
# torch.Size([1, 3, 512, 512])
# output saving successfully
# ./dataset/./DRIVE/test/images/02_test.tif
# torch.Size([1, 3, 512, 512])
# output saving successfully
# ./dataset/./DRIVE/test/images/08_test.tif
# torch.Size([1, 3, 512, 512])
# output saving successfully
# ./dataset/./DRIVE/test/images/13_test.tif
# torch.Size([1, 3, 512, 512])
# output saving successfully
# ./dataset/./DRIVE/test/images/12_test.tif
# torch.Size([1, 3, 512, 512])
# output saving successfully
# ./dataset/./DRIVE/test/images/14_test.tif
# torch.Size([1, 3, 512, 512])
# output saving successfully
# ...
